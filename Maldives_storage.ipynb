# %% [markdown]
# ## Adding sub-annual time slices and storage
# This script adds seasonality and storage to Maldives model/scenario
# For more information on seasonality, please refer to [this tutorial](<https://github.com/iiasa/message_ix/blob/master/tutorial/westeros/westeros_seasonality.ipynb>)

# %%
# Importing required packages
import itertools
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import ixmp
import message_ix

from message_ix.utils import make_df

# %%
mp = ixmp.Platform()

# %%
# Loading a baseline scenario
model = "Maldives energy model"
scen = "baseline"
version = 1
base = message_ix.Scenario(mp, model, scen, version)

# %%
# Cloning to a new scenario for editing
scen = base.clone(scenario='time-slice', keep_solution=False)

# Checking out the scenario for editing
scen.check_out()

# %% [markdown]
# ### 1. Representing sub-annual time slices
# #### 1.1. Modifying sets

# %%
# Adding sub-annual time steps
time_steps = ['day', 'night']
scen.add_set('time', time_steps)

# %%
# Defining a new temporal level
time_level = 'daylight'
scen.add_set('lvl_temporal', time_level)

# Adding temporal hierarchy
for t in time_steps:
    scen.add_set('map_temporal_hierarchy', [time_level, t, 'year'])

# %% [markdown]
# #### 1.2 Modifying parameters

# %%
# Adding duration time
for t in time_steps:
    scen.add_par('duration_time', [t], 1/len(time_steps), '-')

# %% [markdown]
# We define a function for manupulating the data of parameters for each sub-annual time slice. This is used for changing demand, input/output, var_cost, etc.

# %%
# A function for adding sub-annual data to a parameter
def yearly_to_season(scen, parameter, data, filters=None):
    if filters:
        old = scen.par(parameter, filters)
    else:
        old = scen.par(parameter)
    scen.remove_par(parameter, old)
    
    # Finding "time" related indexes and updating the data
    time_idx = [x for x in scen.idx_names(parameter) if 'time' in x]
    for h in data.keys():
        new = old.copy()
    for time in time_idx:
        new[time] = h
        new['value'] = data[h] * old['value']
    scen.add_par(parameter, new)

# %%
# Modifying demand for each time slice
# Electricity demand
demand_data = {'day': 0.4, 'night': 0.60}
filters = {'commodity': 'electricity'}
yearly_to_season(scen, 'demand', demand_data) #added =None

# Here, I just divid them the yearly demand for day and night equally
demand_data = {'day': 0.50, 'night': 0.50}
filters = {'commodity': ['cooling', 'freshwater']}
yearly_to_season(scen, 'demand', demand_data) #added =None

# %%
# Modifying input and output parameters for each time slice
# Output of solar PV at night zero
pv_data = {'day': 1, 'night': 0}
pv_filters = {'technology': 'solar_pv_ppl'}
yearly_to_season(scen, 'output', pv_data, pv_filters)

# Output of other technologies
fixed_data = {'day': 1, 'night': 1}
other_filters = {'technology': ['oil_ppl', 'battery_ppl', 'ac', 'ro_pl', 'swac', 'dscd']}
yearly_to_season(scen, 'output', fixed_data, other_filters)

# Input of all technologies
yearly_to_season(scen, 'input', fixed_data)

# %%
# Modifying capacity factor
# Yearly capacity factor of solar_pv in the baseline scenario
cf_solar = scen.par('capacity_factor', {'technology': 'solar_pv_ppl'})['value'].mean()

# Converting yearly capacity factor to day-night (multiplying CF by 2 for day)
cf_data = {'day': 2, 'night': 0} 
yearly_to_season(scen, 'capacity_factor', cf_data, pv_filters)

# Capacity factor of other technologies remains unchanged in each time slice
yearly_to_season(scen, 'capacity_factor', fixed_data, other_filters)

# %%
# Modifying initial penetration rates for each time slice
half_data = {'day': 0.5, 'night': 0.5} 
yearly_to_season(scen, 'initial_activity_up', half_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'key'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3570         try:
# -> 3571             loc = self._info_axis.get_loc(key)
#    3572         except KeyError:
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#
# KeyError: 'key'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-3dd36eba5759> in <module>
#       1 # Modifying initial penetration rates for each time slice
#       2 half_data = {'day': 0.5, 'night': 0.5}
# ----> 3 yearly_to_season(scen, 'initial_activity_up', half_data)
#
# <ipython-input-70-416bde17fc02> in yearly_to_season(scen, parameter, data, filters)
#      14         new[time] = h
#      15         new['value'] = data[h] * old['value']
# ---> 16     scen.add_par(parameter, new)
#
# ~\Anaconda3\envs\message\lib\site-packages\ixmp\core.py in add_par(self, name, key_or_data, value, unit, comment)
#    1292             # Form the 'key' column from other columns
#    1293             if N_dim > 1:
# -> 1294                 data['key'] = data.apply(partial(as_str_list,
#    1295                                                  idx_names=idx_names),
#    1296                                          axis=1)
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3115         self._ensure_valid_index(value)
#    3116         value = self._sanitize_column(key, value)
# -> 3117         NDFrame._set_item(self, key, value)
#    3118
#    3119         # check if we are modifying a copy
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3572         except KeyError:
#    3573             # This item wasn't present, just insert at end
# -> 3574             self._mgr.insert(len(self._info_axis), key, value)
#    3575             return
#    3576
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1187             value = _safe_reshape(value, (1,) + value.shape)
#    1188
# -> 1189         block = make_block(values=value, ndim=self.ndim, placement=slice(loc, loc + 1))
#    1190
#    1191         for blkno, count in _fast_count_smallints(self.blknos[loc:]):
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2717         values = DatetimeArray._simple_new(values, dtype=dtype)
#    2718
# -> 2719     return klass(values, ndim=ndim, placement=placement)
#    2720
#    2721
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#    2373             values = np.array(values, dtype=object)
#    2374
# -> 2375         super().__init__(values, ndim=ndim, placement=placement)
#    2376
#    2377     @property
#
# ~\Anaconda3\envs\message\lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     127
#     128         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 129             raise ValueError(
#     130                 f"Wrong number of items passed {len(self.values)}, "
#     131                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 6, placement implies 1

# %%
# Modifying historical activity 
hist_data = {'day': 1, 'night': 0}
yearly_to_season(scen, 'historical_activity', hist_data, pv_filters)
# For others divide equally between day and night
hist_data = {'day': 0.5, 'night': 0.5}
yearly_to_season(scen, 'historical_activity', hist_data, other_filters)
# Out:
#    node_loc    technology  year_act      mode time      value unit
# 0  Maldives  solar_pv_ppl      2020  standard  day  1460028.0  MWa
#    node_loc    technology  year_act      mode   time  value unit
# 0  Maldives  solar_pv_ppl      2020  standard  night    0.0  MWa
#    node_loc technology  year_act      mode time       value unit
# 0  Maldives    oil_ppl      2020  standard  day  13870266.0  MWa
# 1  Maldives         ac      2020  standard  day       157.5  MWa
# 2  Maldives      ro_pl      2020  standard  day  14600000.0  MWa
# 3  Maldives       swac      2020  standard  day         0.0  MWa
# 4  Maldives       dscd      2020  standard  day         0.0  MWa
#    node_loc technology  year_act      mode   time       value unit
# 0  Maldives    oil_ppl      2020  standard  night  13870266.0  MWa
# 1  Maldives         ac      2020  standard  night       157.5  MWa
# 2  Maldives      ro_pl      2020  standard  night  14600000.0  MWa
# 3  Maldives       swac      2020  standard  night         0.0  MWa
# 4  Maldives       dscd      2020  standard  night         0.0  MWa

# %%
# Modifying variable cost
yearly_to_season(scen, 'var_cost', fixed_data)
# Out:
#     node_loc technology  year_vtg  year_act      mode time  value     unit
# 0   Maldives    oil_ppl      2020      2025  standard  day   30.0  USD/kWa
# 1   Maldives    oil_ppl      2020      2030  standard  day   30.0  USD/kWa
# 2   Maldives    oil_ppl      2020      2035  standard  day   30.0  USD/kWa
# 3   Maldives    oil_ppl      2020      2040  standard  day   30.0  USD/kWa
# 4   Maldives    oil_ppl      2025      2025  standard  day   30.0  USD/kWa
# ..       ...        ...       ...       ...       ...  ...    ...      ...
# 79  Maldives       dscd      2030      2035  standard  day    0.0  USD/kWa
# 80  Maldives       dscd      2030      2040  standard  day    0.0  USD/kWa
# 81  Maldives       dscd      2035      2035  standard  day    0.0  USD/kWa
# 82  Maldives       dscd      2035      2040  standard  day    0.0  USD/kWa
# 83  Maldives       dscd      2040      2040  standard  day    0.0  USD/kWa
#
# [84 rows x 8 columns]
#     node_loc technology  year_vtg  year_act      mode   time  value     unit
# 0   Maldives    oil_ppl      2020      2025  standard  night   30.0  USD/kWa
# 1   Maldives    oil_ppl      2020      2030  standard  night   30.0  USD/kWa
# 2   Maldives    oil_ppl      2020      2035  standard  night   30.0  USD/kWa
# 3   Maldives    oil_ppl      2020      2040  standard  night   30.0  USD/kWa
# 4   Maldives    oil_ppl      2025      2025  standard  night   30.0  USD/kWa
# ..       ...        ...       ...       ...       ...    ...    ...      ...
# 79  Maldives       dscd      2030      2035  standard  night    0.0  USD/kWa
# 80  Maldives       dscd      2030      2040  standard  night    0.0  USD/kWa
# 81  Maldives       dscd      2035      2035  standard  night    0.0  USD/kWa
# 82  Maldives       dscd      2035      2040  standard  night    0.0  USD/kWa
# 83  Maldives       dscd      2040      2040  standard  night    0.0  USD/kWa
#
# [84 rows x 8 columns]

# %%
# Removing output of solar_pv at night

# %%
scen.commit(comment='introducing seasonality')
scen.set_as_default()

# %%
scen.solve()

# %% [markdown]
# ### 2. Representing storage

# %%
# Cloning to a new scenario for adding storage
sc = scen.clone(scenario='storage', keep_solution=False)

# Checking out the scenario for editing
sc.check_out()

# %% [markdown]
# #### 2.1 Configuring storage sets

# %%
# Adding level of storage
sc.add_set('level', 'store')

# Adding storage technologies (based on the notation of: reservoir, charger, and discharger)
sc.add_set('technology', ['battery_stor', 'dummay', 'battery_ppl'])

# Adding a storage commodity
sc.add_set('commodity', ['dummay'])

# Specifying storage reservoir technology
sc.add_set('storage_tec', 'battery_stor')

# Specifying storage level
sc.add_set('level_storage', 'store')

# Adding mapping for storage and charger/discharger technologies
for tec in ['dummay', 'battery_ppl']:
    sc.add_set('map_tec_storage', ['Maldives', tec, 'battery_stor', 'store',
                                     'electricity'])

# %% [markdown]
# #### 2.2. Configuring storage parameters

# %%
# Adding the order of time slices
sc.add_par('time_order', ['daylight', 'day'], 1, '-')
sc.add_par('time_order', ['daylight', 'night'], 2, '-')

# %%
# Adding output and input for storage technologies
# Loading the output of battery
data = sc.par('output', {'technology': 'battery_ppl'})

# Order of data: ['commodity', 'level']
output_spec = {'battery_stor': ['dummay', 'final'],
               'dummay': ['electricity', 'store'],
               }
for tec, item in output_spec.items():
    data['technology'] = tec
    data['commodity'] = item[0]
    data['level'] = item[1]
    sc.add_par('output', data)

# Configuring input parameter
data = data.rename({'node_dest': 'node_origin', 'time_dest': 'time_origin'}, axis=1)
input_spec = {'battery_stor': ['dummay', 'final'],
              'dummay': ['electricity', 'final'],
              'battery_ppl': ['electricity', 'store'],
              }

for tec, item in input_spec.items():
    data['technology'] = tec
    data['commodity'] = item[0]
    data['level'] = item[1]
    sc.add_par('input', data)
# Out:
#     node_loc    technology  year_vtg  year_act      mode node_dest commodity  \
# 0   Maldives  battery_stor      2020      2025  standard  Maldives    dummay
# 1   Maldives  battery_stor      2020      2030  standard  Maldives    dummay
# 2   Maldives  battery_stor      2020      2035  standard  Maldives    dummay
# 3   Maldives  battery_stor      2020      2040  standard  Maldives    dummay
# 4   Maldives  battery_stor      2025      2025  standard  Maldives    dummay
# 5   Maldives  battery_stor      2025      2030  standard  Maldives    dummay
# 6   Maldives  battery_stor      2025      2035  standard  Maldives    dummay
# 7   Maldives  battery_stor      2025      2040  standard  Maldives    dummay
# 8   Maldives  battery_stor      2030      2030  standard  Maldives    dummay
# 9   Maldives  battery_stor      2030      2035  standard  Maldives    dummay
# 10  Maldives  battery_stor      2030      2040  standard  Maldives    dummay
# 11  Maldives  battery_stor      2035      2035  standard  Maldives    dummay
# 12  Maldives  battery_stor      2035      2040  standard  Maldives    dummay
# 13  Maldives  battery_stor      2040      2040  standard  Maldives    dummay
# 14  Maldives  battery_stor      2020      2025  standard  Maldives    dummay
# 15  Maldives  battery_stor      2020      2030  standard  Maldives    dummay
# 16  Maldives  battery_stor      2020      2035  standard  Maldives    dummay
# 17  Maldives  battery_stor      2020      2040  standard  Maldives    dummay
# 18  Maldives  battery_stor      2025      2025  standard  Maldives    dummay
# 19  Maldives  battery_stor      2025      2030  standard  Maldives    dummay
# 20  Maldives  battery_stor      2025      2035  standard  Maldives    dummay
# 21  Maldives  battery_stor      2025      2040  standard  Maldives    dummay
# 22  Maldives  battery_stor      2030      2030  standard  Maldives    dummay
# 23  Maldives  battery_stor      2030      2035  standard  Maldives    dummay
# 24  Maldives  battery_stor      2030      2040  standard  Maldives    dummay
# 25  Maldives  battery_stor      2035      2035  standard  Maldives    dummay
# 26  Maldives  battery_stor      2035      2040  standard  Maldives    dummay
# 27  Maldives  battery_stor      2040      2040  standard  Maldives    dummay
#
#     level   time time_dest  value unit
# 0   final    day       day    1.0  MWa
# 1   final    day       day    1.0  MWa
# 2   final    day       day    1.0  MWa
# 3   final    day       day    1.0  MWa
# 4   final    day       day    1.0  MWa
# 5   final    day       day    1.0  MWa
# 6   final    day       day    1.0  MWa
# 7   final    day       day    1.0  MWa
# 8   final    day       day    1.0  MWa
# 9   final    day       day    1.0  MWa
# 10  final    day       day    1.0  MWa
# 11  final    day       day    1.0  MWa
# 12  final    day       day    1.0  MWa
# 13  final    day       day    1.0  MWa
# 14  final  night     night    1.0  MWa
# 15  final  night     night    1.0  MWa
# 16  final  night     night    1.0  MWa
# 17  final  night     night    1.0  MWa
# 18  final  night     night    1.0  MWa
# 19  final  night     night    1.0  MWa
# 20  final  night     night    1.0  MWa
# 21  final  night     night    1.0  MWa
# 22  final  night     night    1.0  MWa
# 23  final  night     night    1.0  MWa
# 24  final  night     night    1.0  MWa
# 25  final  night     night    1.0  MWa
# 26  final  night     night    1.0  MWa
# 27  final  night     night    1.0  MWa
#     node_loc technology  year_vtg  year_act      mode node_dest    commodity  \
# 0   Maldives     dummay      2020      2025  standard  Maldives  electricity
# 1   Maldives     dummay      2020      2030  standard  Maldives  electricity
# 2   Maldives     dummay      2020      2035  standard  Maldives  electricity
# 3   Maldives     dummay      2020      2040  standard  Maldives  electricity
# 4   Maldives     dummay      2025      2025  standard  Maldives  electricity
# 5   Maldives     dummay      2025      2030  standard  Maldives  electricity
# 6   Maldives     dummay      2025      2035  standard  Maldives  electricity
# 7   Maldives     dummay      2025      2040  standard  Maldives  electricity
# 8   Maldives     dummay      2030      2030  standard  Maldives  electricity
# 9   Maldives     dummay      2030      2035  standard  Maldives  electricity
# 10  Maldives     dummay      2030      2040  standard  Maldives  electricity
# 11  Maldives     dummay      2035      2035  standard  Maldives  electricity
# 12  Maldives     dummay      2035      2040  standard  Maldives  electricity
# 13  Maldives     dummay      2040      2040  standard  Maldives  electricity
# 14  Maldives     dummay      2020      2025  standard  Maldives  electricity
# 15  Maldives     dummay      2020      2030  standard  Maldives  electricity
# 16  Maldives     dummay      2020      2035  standard  Maldives  electricity
# 17  Maldives     dummay      2020      2040  standard  Maldives  electricity
# 18  Maldives     dummay      2025      2025  standard  Maldives  electricity
# 19  Maldives     dummay      2025      2030  standard  Maldives  electricity
# 20  Maldives     dummay      2025      2035  standard  Maldives  electricity
# 21  Maldives     dummay      2025      2040  standard  Maldives  electricity
# 22  Maldives     dummay      2030      2030  standard  Maldives  electricity
# 23  Maldives     dummay      2030      2035  standard  Maldives  electricity
# 24  Maldives     dummay      2030      2040  standard  Maldives  electricity
# 25  Maldives     dummay      2035      2035  standard  Maldives  electricity
# 26  Maldives     dummay      2035      2040  standard  Maldives  electricity
# 27  Maldives     dummay      2040      2040  standard  Maldives  electricity
#
#     level   time time_dest  value unit
# 0   store    day       day    1.0  MWa
# 1   store    day       day    1.0  MWa
# 2   store    day       day    1.0  MWa
# 3   store    day       day    1.0  MWa
# 4   store    day       day    1.0  MWa
# 5   store    day       day    1.0  MWa
# 6   store    day       day    1.0  MWa
# 7   store    day       day    1.0  MWa
# 8   store    day       day    1.0  MWa
# 9   store    day       day    1.0  MWa
# 10  store    day       day    1.0  MWa
# 11  store    day       day    1.0  MWa
# 12  store    day       day    1.0  MWa
# 13  store    day       day    1.0  MWa
# 14  store  night     night    1.0  MWa
# 15  store  night     night    1.0  MWa
# 16  store  night     night    1.0  MWa
# 17  store  night     night    1.0  MWa
# 18  store  night     night    1.0  MWa
# 19  store  night     night    1.0  MWa
# 20  store  night     night    1.0  MWa
# 21  store  night     night    1.0  MWa
# 22  store  night     night    1.0  MWa
# 23  store  night     night    1.0  MWa
# 24  store  night     night    1.0  MWa
# 25  store  night     night    1.0  MWa
# 26  store  night     night    1.0  MWa
# 27  store  night     night    1.0  MWa
#     node_loc    technology  year_vtg  year_act      mode node_origin  \
# 0   Maldives  battery_stor      2020      2025  standard    Maldives
# 1   Maldives  battery_stor      2020      2030  standard    Maldives
# 2   Maldives  battery_stor      2020      2035  standard    Maldives
# 3   Maldives  battery_stor      2020      2040  standard    Maldives
# 4   Maldives  battery_stor      2025      2025  standard    Maldives
# 5   Maldives  battery_stor      2025      2030  standard    Maldives
# 6   Maldives  battery_stor      2025      2035  standard    Maldives
# 7   Maldives  battery_stor      2025      2040  standard    Maldives
# 8   Maldives  battery_stor      2030      2030  standard    Maldives
# 9   Maldives  battery_stor      2030      2035  standard    Maldives
# 10  Maldives  battery_stor      2030      2040  standard    Maldives
# 11  Maldives  battery_stor      2035      2035  standard    Maldives
# 12  Maldives  battery_stor      2035      2040  standard    Maldives
# 13  Maldives  battery_stor      2040      2040  standard    Maldives
# 14  Maldives  battery_stor      2020      2025  standard    Maldives
# 15  Maldives  battery_stor      2020      2030  standard    Maldives
# 16  Maldives  battery_stor      2020      2035  standard    Maldives
# 17  Maldives  battery_stor      2020      2040  standard    Maldives
# 18  Maldives  battery_stor      2025      2025  standard    Maldives
# 19  Maldives  battery_stor      2025      2030  standard    Maldives
# 20  Maldives  battery_stor      2025      2035  standard    Maldives
# 21  Maldives  battery_stor      2025      2040  standard    Maldives
# 22  Maldives  battery_stor      2030      2030  standard    Maldives
# 23  Maldives  battery_stor      2030      2035  standard    Maldives
# 24  Maldives  battery_stor      2030      2040  standard    Maldives
# 25  Maldives  battery_stor      2035      2035  standard    Maldives
# 26  Maldives  battery_stor      2035      2040  standard    Maldives
# 27  Maldives  battery_stor      2040      2040  standard    Maldives
#
#    commodity  level   time time_origin  value unit
# 0     dummay  final    day         day    1.0  MWa
# 1     dummay  final    day         day    1.0  MWa
# 2     dummay  final    day         day    1.0  MWa
# 3     dummay  final    day         day    1.0  MWa
# 4     dummay  final    day         day    1.0  MWa
# 5     dummay  final    day         day    1.0  MWa
# 6     dummay  final    day         day    1.0  MWa
# 7     dummay  final    day         day    1.0  MWa
# 8     dummay  final    day         day    1.0  MWa
# 9     dummay  final    day         day    1.0  MWa
# 10    dummay  final    day         day    1.0  MWa
# 11    dummay  final    day         day    1.0  MWa
# 12    dummay  final    day         day    1.0  MWa
# 13    dummay  final    day         day    1.0  MWa
# 14    dummay  final  night       night    1.0  MWa
# 15    dummay  final  night       night    1.0  MWa
# 16    dummay  final  night       night    1.0  MWa
# 17    dummay  final  night       night    1.0  MWa
# 18    dummay  final  night       night    1.0  MWa
# 19    dummay  final  night       night    1.0  MWa
# 20    dummay  final  night       night    1.0  MWa
# 21    dummay  final  night       night    1.0  MWa
# 22    dummay  final  night       night    1.0  MWa
# 23    dummay  final  night       night    1.0  MWa
# 24    dummay  final  night       night    1.0  MWa
# 25    dummay  final  night       night    1.0  MWa
# 26    dummay  final  night       night    1.0  MWa
# 27    dummay  final  night       night    1.0  MWa
#     node_loc technology  year_vtg  year_act      mode node_origin  \
# 0   Maldives     dummay      2020      2025  standard    Maldives
# 1   Maldives     dummay      2020      2030  standard    Maldives
# 2   Maldives     dummay      2020      2035  standard    Maldives
# 3   Maldives     dummay      2020      2040  standard    Maldives
# 4   Maldives     dummay      2025      2025  standard    Maldives
# 5   Maldives     dummay      2025      2030  standard    Maldives
# 6   Maldives     dummay      2025      2035  standard    Maldives
# 7   Maldives     dummay      2025      2040  standard    Maldives
# 8   Maldives     dummay      2030      2030  standard    Maldives
# 9   Maldives     dummay      2030      2035  standard    Maldives
# 10  Maldives     dummay      2030      2040  standard    Maldives
# 11  Maldives     dummay      2035      2035  standard    Maldives
# 12  Maldives     dummay      2035      2040  standard    Maldives
# 13  Maldives     dummay      2040      2040  standard    Maldives
# 14  Maldives     dummay      2020      2025  standard    Maldives
# 15  Maldives     dummay      2020      2030  standard    Maldives
# 16  Maldives     dummay      2020      2035  standard    Maldives
# 17  Maldives     dummay      2020      2040  standard    Maldives
# 18  Maldives     dummay      2025      2025  standard    Maldives
# 19  Maldives     dummay      2025      2030  standard    Maldives
# 20  Maldives     dummay      2025      2035  standard    Maldives
# 21  Maldives     dummay      2025      2040  standard    Maldives
# 22  Maldives     dummay      2030      2030  standard    Maldives
# 23  Maldives     dummay      2030      2035  standard    Maldives
# 24  Maldives     dummay      2030      2040  standard    Maldives
# 25  Maldives     dummay      2035      2035  standard    Maldives
# 26  Maldives     dummay      2035      2040  standard    Maldives
# 27  Maldives     dummay      2040      2040  standard    Maldives
#
#       commodity  level   time time_origin  value unit
# 0   electricity  final    day         day    1.0  MWa
# 1   electricity  final    day         day    1.0  MWa
# 2   electricity  final    day         day    1.0  MWa
# 3   electricity  final    day         day    1.0  MWa
# 4   electricity  final    day         day    1.0  MWa
# 5   electricity  final    day         day    1.0  MWa
# 6   electricity  final    day         day    1.0  MWa
# 7   electricity  final    day         day    1.0  MWa
# 8   electricity  final    day         day    1.0  MWa
# 9   electricity  final    day         day    1.0  MWa
# 10  electricity  final    day         day    1.0  MWa
# 11  electricity  final    day         day    1.0  MWa
# 12  electricity  final    day         day    1.0  MWa
# 13  electricity  final    day         day    1.0  MWa
# 14  electricity  final  night       night    1.0  MWa
# 15  electricity  final  night       night    1.0  MWa
# 16  electricity  final  night       night    1.0  MWa
# 17  electricity  final  night       night    1.0  MWa
# 18  electricity  final  night       night    1.0  MWa
# 19  electricity  final  night       night    1.0  MWa
# 20  electricity  final  night       night    1.0  MWa
# 21  electricity  final  night       night    1.0  MWa
# 22  electricity  final  night       night    1.0  MWa
# 23  electricity  final  night       night    1.0  MWa
# 24  electricity  final  night       night    1.0  MWa
# 25  electricity  final  night       night    1.0  MWa
# 26  electricity  final  night       night    1.0  MWa
# 27  electricity  final  night       night    1.0  MWa
#     node_loc   technology  year_vtg  year_act      mode node_origin  \
# 0   Maldives  battery_ppl      2020      2025  standard    Maldives
# 1   Maldives  battery_ppl      2020      2030  standard    Maldives
# 2   Maldives  battery_ppl      2020      2035  standard    Maldives
# 3   Maldives  battery_ppl      2020      2040  standard    Maldives
# 4   Maldives  battery_ppl      2025      2025  standard    Maldives
# 5   Maldives  battery_ppl      2025      2030  standard    Maldives
# 6   Maldives  battery_ppl      2025      2035  standard    Maldives
# 7   Maldives  battery_ppl      2025      2040  standard    Maldives
# 8   Maldives  battery_ppl      2030      2030  standard    Maldives
# 9   Maldives  battery_ppl      2030      2035  standard    Maldives
# 10  Maldives  battery_ppl      2030      2040  standard    Maldives
# 11  Maldives  battery_ppl      2035      2035  standard    Maldives
# 12  Maldives  battery_ppl      2035      2040  standard    Maldives
# 13  Maldives  battery_ppl      2040      2040  standard    Maldives
# 14  Maldives  battery_ppl      2020      2025  standard    Maldives
# 15  Maldives  battery_ppl      2020      2030  standard    Maldives
# 16  Maldives  battery_ppl      2020      2035  standard    Maldives
# 17  Maldives  battery_ppl      2020      2040  standard    Maldives
# 18  Maldives  battery_ppl      2025      2025  standard    Maldives
# 19  Maldives  battery_ppl      2025      2030  standard    Maldives
# 20  Maldives  battery_ppl      2025      2035  standard    Maldives
# 21  Maldives  battery_ppl      2025      2040  standard    Maldives
# 22  Maldives  battery_ppl      2030      2030  standard    Maldives
# 23  Maldives  battery_ppl      2030      2035  standard    Maldives
# 24  Maldives  battery_ppl      2030      2040  standard    Maldives
# 25  Maldives  battery_ppl      2035      2035  standard    Maldives
# 26  Maldives  battery_ppl      2035      2040  standard    Maldives
# 27  Maldives  battery_ppl      2040      2040  standard    Maldives
#
#       commodity  level   time time_origin  value unit
# 0   electricity  store    day         day    1.0  MWa
# 1   electricity  store    day         day    1.0  MWa
# 2   electricity  store    day         day    1.0  MWa
# 3   electricity  store    day         day    1.0  MWa
# 4   electricity  store    day         day    1.0  MWa
# 5   electricity  store    day         day    1.0  MWa
# 6   electricity  store    day         day    1.0  MWa
# 7   electricity  store    day         day    1.0  MWa
# 8   electricity  store    day         day    1.0  MWa
# 9   electricity  store    day         day    1.0  MWa
# 10  electricity  store    day         day    1.0  MWa
# 11  electricity  store    day         day    1.0  MWa
# 12  electricity  store    day         day    1.0  MWa
# 13  electricity  store    day         day    1.0  MWa
# 14  electricity  store  night       night    1.0  MWa
# 15  electricity  store  night       night    1.0  MWa
# 16  electricity  store  night       night    1.0  MWa
# 17  electricity  store  night       night    1.0  MWa
# 18  electricity  store  night       night    1.0  MWa
# 19  electricity  store  night       night    1.0  MWa
# 20  electricity  store  night       night    1.0  MWa
# 21  electricity  store  night       night    1.0  MWa
# 22  electricity  store  night       night    1.0  MWa
# 23  electricity  store  night       night    1.0  MWa
# 24  electricity  store  night       night    1.0  MWa
# 25  electricity  store  night       night    1.0  MWa
# 26  electricity  store  night       night    1.0  MWa
# 27  electricity  store  night       night    1.0  MWa

# %%
# Adding storage self-discharge (as %) and initial content (assuming 3% loss of battery charge between day and night (6%/day))
for year, h in itertools.product(set(sc.set('year')), time_steps):
    storage_spec = ['Maldives', 'battery_stor', 'store', 'dummay', year, h]
    sc.add_par('storage_self_discharge', storage_spec, 0.03, '%')

    # Adding initial content of storage (optional)
    initial_value = 0
    storage_spec = ['Maldives', 'battery_stor', 'store', 'dummay', year, 'day']
    sc.add_par('storage_initial', storage_spec, initial_value, 'GWa')

# %% [markdown]
# #### Committing and solving

# %%
sc.commit('storage setup added')
sc.solve(var_list=['STORAGE', 'STORAGE_CHARGE', 'STORAGE_INIT'])

# %%
# The battery doesn't work as it is expensive with PV (oil_ppl supplies all demand)
sc.var('STORAGE')
# Out:
#         node    technology  level    commodity  year   time  lvl  \
# 0   Maldives  battery_stor  store  electricity  2025   year  0.0
# 1   Maldives  battery_stor  store  electricity  2025    day  0.0
# 2   Maldives  battery_stor  store  electricity  2025  night  0.0
# 3   Maldives  battery_stor  store  electricity  2030   year  0.0
# 4   Maldives  battery_stor  store  electricity  2030    day  0.0
# 5   Maldives  battery_stor  store  electricity  2030  night  0.0
# 6   Maldives  battery_stor  store  electricity  2035   year  0.0
# 7   Maldives  battery_stor  store  electricity  2035    day  0.0
# 8   Maldives  battery_stor  store  electricity  2035  night  0.0
# 9   Maldives  battery_stor  store  electricity  2040   year  0.0
# 10  Maldives  battery_stor  store  electricity  2040    day  0.0
# 11  Maldives  battery_stor  store  electricity  2040  night  0.0
#
#               mrg
# 0    0.000000e+00
# 1   4.940656e-324
# 2    0.000000e+00
# 3    0.000000e+00
# 4   4.940656e-324
# 5    0.000000e+00
# 6    0.000000e+00
# 7    0.000000e+00
# 8   4.940656e-324
# 9    0.000000e+00
# 10   0.000000e+00
# 11  4.940656e-324

# %%
# A new scenario with lower cost of battery or bound on oil
sc_lo = sc.clone(scenario='storage-oil-bound', keep_solution=False)
sc_lo.check_out()

# %%
# Reducing inv_cost
for parname in ['inv_cost']:
    df = sc_lo.par(parname, {'technology': 'battery_ppl', })
    df['value'] *= 1
    sc_lo.add_par(parname, df)
# Out:
#    node_loc   technology  year_vtg  value    unit
# 0  Maldives  battery_ppl      2025  800.0  USD/kW
# 1  Maldives  battery_ppl      2030  800.0  USD/kW
# 2  Maldives  battery_ppl      2035  800.0  USD/kW
# 3  Maldives  battery_ppl      2040  800.0  USD/kW

# %%
# bound on activity of oil at night
base_act = {
    'node_loc': 'Maldives',
    'year_act': list(set(sc_lo.set('year'))),
    'mode': 'standard',
    'time': 'night',
    'unit': 'MWa',
}

new_activity = {'oil_ppl': 100}

for tec, val in new_activity.items():
    df = make_df(base_act, technology=tec, value=val)
    sc_lo.add_par('bound_activity_up', df)
# Out:
#    node_loc  year_act      mode   time unit technology  value
# 0  Maldives      2020  standard  night  MWa    oil_ppl    100
# 1  Maldives      2025  standard  night  MWa    oil_ppl    100
# 2  Maldives      2030  standard  night  MWa    oil_ppl    100
# 3  Maldives      2035  standard  night  MWa    oil_ppl    100
# 4  Maldives      2040  standard  night  MWa    oil_ppl    100

# %%
sc_lo.commit('')
sc_lo.solve(var_list=['STORAGE', 'STORAGE_CHARGE', 'STORAGE_INIT'])

# %%
sc_lo.var('STORAGE')
# Out:
#         node    technology  level    commodity  year   time         lvl  \
# 0   Maldives  battery_stor  store  electricity  2025   year    0.000000
# 1   Maldives  battery_stor  store  electricity  2025    day  186.004677
# 2   Maldives  battery_stor  store  electricity  2025  night    0.000000
# 3   Maldives  battery_stor  store  electricity  2030   year    0.000000
# 4   Maldives  battery_stor  store  electricity  2030    day  211.740177
# 5   Maldives  battery_stor  store  electricity  2030  night    0.000000
# 6   Maldives  battery_stor  store  electricity  2035   year    0.000000
# 7   Maldives  battery_stor  store  electricity  2035    day  224.308677
# 8   Maldives  battery_stor  store  electricity  2035  night    0.000000
# 9   Maldives  battery_stor  store  electricity  2040   year    0.000000
# 10  Maldives  battery_stor  store  electricity  2040    day  228.498177
# 11  Maldives  battery_stor  store  electricity  2040  night    0.000000
#
#               mrg
# 0    0.000000e+00
# 1    0.000000e+00
# 2   4.940656e-324
# 3    0.000000e+00
# 4    0.000000e+00
# 5   4.940656e-324
# 6    0.000000e+00
# 7    0.000000e+00
# 8   4.940656e-324
# 9    0.000000e+00
# 10   0.000000e+00
# 11  4.940656e-324

# %%
mp.close_db()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7cf9c998c566> in <module>
# ----> 1 mp.close_db()
#
# NameError: name 'mp' is not defined
